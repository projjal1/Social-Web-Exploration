# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'angLxNBCYgyEAaX1AWacsl368'
CONSUMER_SECRET ='poAm57HYVDYIp1jbGctjjUrYnRVz86IWa4pI6LukKqoalNk4fO'
OAUTH_TOKEN = '1277968300912160771-d2sw7380bkQWaOtxtt4AcsibK9jluY'
OAUTH_TOKEN_SECRET = 'ZZ4wtvlsYgURppngcHZzhQ7vBsMEELIQeuciVtYKKYwDQ'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print (twitter_api)
# Out:
# <twitter.api.Twitter object at 0x00000230D28A08D0>

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print (world_trends)
print()
print (us_trends)
# Out:
# [{'trends': [{'name': '#TrustInYugyeomDay', 'url': 'http://twitter.com/search?q=%23TrustInYugyeomDay', 'promoted_content': None, 'query': '%23TrustInYugyeomDay', 'tweet_volume': 85266}, {'name': '#아가새의민들레_유겸아생일축하해', 'url': 'http://twitter.com/search?q=%23%EC%95%84%EA%B0%80%EC%83%88%EC%9D%98%EB%AF%BC%EB%93%A4%EB%A0%88_%EC%9C%A0%EA%B2%B8%EC%95%84%EC%83%9D%EC%9D%BC%EC%B6%95%ED%95%98%ED%95%B4', 'promoted_content': None, 'query': '%23%EC%95%84%EA%B0%80%EC%83%88%EC%9D%98%EB%AF%BC%EB%93%A4%EB%A0%88_%EC%9C%A0%EA%B2%B8%EC%95%84%EC%83%9D%EC%9D%BC%EC%B6%95%ED%95%98%ED%95%B4', 'tweet_volume': 40909}, {'name': '#3DaysBEforeBE', 'url': 'http://twitter.com/search?q=%233DaysBEforeBE', 'promoted_content': None, 'query': '%233DaysBEforeBE', 'tweet_volume': 65067}, {'name': 'Moderna', 'url': 'http://twitter.com/search?q=Moderna', 'promoted_content': None, 'query': 'Moderna', 'tweet_volume': 185200}, {'name': '#İbrahimAtabeyTutuklansın', 'url': 'http://twitter.com/search?q=%23%C4%B0brahimAtabeyTutuklans%C4%B1n', 'promoted_content': None, 'query': '%23%C4%B0brahimAtabeyTutuklans%C4%B1n', 'tweet_volume': None}, {'name': '#しゃべくり007', 'url': 'http://twitter.com/search?q=%23%E3%81%97%E3%82%83%E3%81%B9%E3%81%8F%E3%82%8A007', 'promoted_content': None, 'query': '%23%E3%81%97%E3%82%83%E3%81%B9%E3%81%8F%E3%82%8A007', 'tweet_volume': 31623}, {'name': 'Wrexham', 'url': 'http://twitter.com/search?q=Wrexham', 'promoted_content': None, 'query': 'Wrexham', 'tweet_volume': 12389}, {'name': 'KIM TAEHYUNG', 'url': 'http://twitter.com/search?q=%22KIM+TAEHYUNG%22', 'promoted_content': None, 'query': '%22KIM+TAEHYUNG%22', 'tweet_volume': 95800}, {'name': 'Space Karen', 'url': 'http://twitter.com/search?q=%22Space+Karen%22', 'promoted_content': None, 'query': '%22Space+Karen%22', 'tweet_volume': 17840}, {'name': 'PSYCHO-PASS', 'url': 'http://twitter.com/search?q=PSYCHO-PASS', 'promoted_content': None, 'query': 'PSYCHO-PASS', 'tweet_volume': None}, {'name': '花澤さん', 'url': 'http://twitter.com/search?q=%E8%8A%B1%E6%BE%A4%E3%81%95%E3%82%93', 'promoted_content': None, 'query': '%E8%8A%B1%E6%BE%A4%E3%81%95%E3%82%93', 'tweet_volume': 18004}, {'name': '日野さん', 'url': 'http://twitter.com/search?q=%E6%97%A5%E9%87%8E%E3%81%95%E3%82%93', 'promoted_content': None, 'query': '%E6%97%A5%E9%87%8E%E3%81%95%E3%82%93', 'tweet_volume': 16333}, {'name': 'ストII', 'url': 'http://twitter.com/search?q=%E3%82%B9%E3%83%88II', 'promoted_content': None, 'query': '%E3%82%B9%E3%83%88II', 'tweet_volume': None}, {'name': 'えいたそ卒業', 'url': 'http://twitter.com/search?q=%E3%81%88%E3%81%84%E3%81%9F%E3%81%9D%E5%8D%92%E6%A5%AD', 'promoted_content': None, 'query': '%E3%81%88%E3%81%84%E3%81%9F%E3%81%9D%E5%8D%92%E6%A5%AD', 'tweet_volume': None}, {'name': 'Mahrez', 'url': 'http://twitter.com/search?q=Mahrez', 'promoted_content': None, 'query': 'Mahrez', 'tweet_volume': 13328}, {'name': 'Kishimoto', 'url': 'http://twitter.com/search?q=Kishimoto', 'promoted_content': None, 'query': 'Kishimoto', 'tweet_volume': 46675}, {'name': 'ざーさん', 'url': 'http://twitter.com/search?q=%E3%81%96%E3%83%BC%E3%81%95%E3%82%93', 'promoted_content': None, 'query': '%E3%81%96%E3%83%BC%E3%81%95%E3%82%93', 'tweet_volume': 11183}, {'name': 'ASIM RIAZ X DJ SNAKE', 'url': 'http://twitter.com/search?q=%22ASIM+RIAZ+X+DJ+SNAKE%22', 'promoted_content': None, 'query': '%22ASIM+RIAZ+X+DJ+SNAKE%22', 'tweet_volume': 106288}, {'name': 'Vcut', 'url': 'http://twitter.com/search?q=Vcut', 'promoted_content': None, 'query': 'Vcut', 'tweet_volume': 418096}, {'name': 'Bruce Brown', 'url': 'http://twitter.com/search?q=%22Bruce+Brown%22', 'promoted_content': None, 'query': '%22Bruce+Brown%22', 'tweet_volume': None}, {'name': 'Providencia', 'url': 'http://twitter.com/search?q=Providencia', 'promoted_content': None, 'query': 'Providencia', 'tweet_volume': 25801}, {'name': '花澤香菜', 'url': 'http://twitter.com/search?q=%E8%8A%B1%E6%BE%A4%E9%A6%99%E8%8F%9C', 'promoted_content': None, 'query': '%E8%8A%B1%E6%BE%A4%E9%A6%99%E8%8F%9C', 'tweet_volume': 23979}, {'name': 'Chi ...
#
# [{'trends': [{'name': '#MondayMotivation', 'url': 'http://twitter.com/search?q=%23MondayMotivation', 'promoted_content': None, 'query': '%23MondayMotivation', 'tweet_volume': 64115}, {'name': 'Moderna', 'url': 'http://twitter.com/search?q=Moderna', 'promoted_content': None, 'query': 'Moderna', 'tweet_volume': 185800}, {'name': '#mondaythoughts', 'url': 'http://twitter.com/search?q=%23mondaythoughts', 'promoted_content': None, 'query': '%23mondaythoughts', 'tweet_volume': 44208}, {'name': 'Space Karen', 'url': 'http://twitter.com/search?q=%22Space+Karen%22', 'promoted_content': None, 'query': '%22Space+Karen%22', 'tweet_volume': 17928}, {'name': '#FreePcMonday', 'url': 'http://twitter.com/search?q=%23FreePcMonday', 'promoted_content': None, 'query': '%23FreePcMonday', 'tweet_volume': 11493}, {'name': '#MondayMorning', 'url': 'http://twitter.com/search?q=%23MondayMorning', 'promoted_content': None, 'query': '%23MondayMorning', 'tweet_volume': 16432}, {'name': '#PatIDontWantToOverreactBUT', 'url': 'http://twitter.com/search?q=%23PatIDontWantToOverreactBUT', 'promoted_content': None, 'query': '%23PatIDontWantToOverreactBUT', 'tweet_volume': None}, {'name': 'Bruce Brown', 'url': 'http://twitter.com/search?q=%22Bruce+Brown%22', 'promoted_content': None, 'query': '%22Bruce+Brown%22', 'tweet_volume': None}, {'name': 'Candace Owens', 'url': 'http://twitter.com/search?q=%22Candace+Owens%22', 'promoted_content': None, 'query': '%22Candace+Owens%22', 'tweet_volume': 16663}, {'name': 'Category 5', 'url': 'http://twitter.com/search?q=%22Category+5%22', 'promoted_content': None, 'query': '%22Category+5%22', 'tweet_volume': 13122}, {'name': 'Musa', 'url': 'http://twitter.com/search?q=Musa', 'promoted_content': None, 'query': 'Musa', 'tweet_volume': 24797}, {'name': 'mRNA', 'url': 'http://twitter.com/search?q=mRNA', 'promoted_content': None, 'query': 'mRNA', 'tweet_volume': 21361}, {'name': 'China Plague', 'url': 'http://twitter.com/search?q=%22China+Plague%22', 'promoted_content': None, 'query': '%22China+Plague%22', 'tweet_volume': 18540}, {'name': 'Victory Monday', 'url': 'http://twitter.com/search?q=%22Victory+Monday%22', 'promoted_content': None, 'query': '%22Victory+Monday%22', 'tweet_volume': None}, {'name': 'Cat 5', 'url': 'http://twitter.com/search?q=%22Cat+5%22', 'promoted_content': None, 'query': '%22Cat+5%22', 'tweet_volume': None}, {'name': 'Really GREAT', 'url': 'http://twitter.com/search?q=%22Really+GREAT%22', 'promoted_content': None, 'query': '%22Really+GREAT%22', 'tweet_volume': 60004}, {'name': 'Herlock Sholmes', 'url': 'http://twitter.com/search?q=%22Herlock+Sholmes%22', 'promoted_content': None, 'query': '%22Herlock+Sholmes%22', 'tweet_volume': None}, {'name': 'Historians', 'url': 'http://twitter.com/search?q=Historians', 'promoted_content': None, 'query': 'Historians', 'tweet_volume': 23540}, {'name': 'Central America', 'url': 'http://twitter.com/search?q=%22Central+America%22', 'promoted_content': None, 'query': '%22Central+America%22', 'tweet_volume': 14744}, {'name': 'VIVI FROM LOONA', 'url': 'http://twitter.com/search?q=%22VIVI+FROM+LOONA%22', 'promoted_content': None, 'query': '%22VIVI+FROM+LOONA%22', 'tweet_volume': None}, {'name': 'Nicaragua', 'url': 'http://twitter.com/search?q=Nicaragua', 'promoted_content': None, 'query': 'Nicaragua', 'tweet_volume': 49025}, {'name': "NO YOU DIDN'T", 'url': 'http://twitter.com/search?q=%22NO+YOU+DIDN%27T%22', 'promoted_content': None, 'query': '%22NO+YOU+DIDN%27T%22', 'tweet_volume': 38148}, {'name': 'Wrexham', 'url': 'http://twitter.com/search?q=Wrexham', 'promoted_content': None, 'query': 'Wrexham', 'tweet_volume': 12473}, {'name': 'Scott Atlas', 'url': 'http://twitter.com/search?q=%22Scott+Atlas%22', 'promoted_content': None, 'query': '%22Scott+Atlas%22', 'tweet_volume': 41703}, {'name': 'Kishimoto', 'url': 'http://twitter.com/search?q=Kishimoto', 'promoted_content': None, 'query': 'Kishimoto', 'tweet_volume': 46675}, {'name': 'Another Monday', 'url': 'http://twitter.com/sear ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print (json.dumps(world_trends, indent=1))
print()
print (json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#TrustInYugyeomDay",
#     "url": "http://twitter.com/search?q=%23TrustInYugyeomDay",
#     "promoted_content": null,
#     "query": "%23TrustInYugyeomDay",
#     "tweet_volume": 85266
#    },
#    {
#     "name": "#\uc544\uac00\uc0c8\uc758\ubbfc\ub4e4\ub808_\uc720\uacb8\uc544\uc0dd\uc77c\ucd95\ud558\ud574",
#     "url": "http://twitter.com/search?q=%23%EC%95%84%EA%B0%80%EC%83%88%EC%9D%98%EB%AF%BC%EB%93%A4%EB%A0%88_%EC%9C%A0%EA%B2%B8%EC%95%84%EC%83%9D%EC%9D%BC%EC%B6%95%ED%95%98%ED%95%B4",
#     "promoted_content": null,
#     "query": "%23%EC%95%84%EA%B0%80%EC%83%88%EC%9D%98%EB%AF%BC%EB%93%A4%EB%A0%88_%EC%9C%A0%EA%B2%B8%EC%95%84%EC%83%9D%EC%9D%BC%EC%B6%95%ED%95%98%ED%95%B4",
#     "tweet_volume": 40909
#    },
#    {
#     "name": "#3DaysBEforeBE",
#     "url": "http://twitter.com/search?q=%233DaysBEforeBE",
#     "promoted_content": null,
#     "query": "%233DaysBEforeBE",
#     "tweet_volume": 65067
#    },
#    {
#     "name": "Moderna",
#     "url": "http://twitter.com/search?q=Moderna",
#     "promoted_content": null,
#     "query": "Moderna",
#     "tweet_volume": 185200
#    },
#    {
#     "name": "#\u0130brahimAtabeyTutuklans\u0131n",
#     "url": "http://twitter.com/search?q=%23%C4%B0brahimAtabeyTutuklans%C4%B1n",
#     "promoted_content": null,
#     "query": "%23%C4%B0brahimAtabeyTutuklans%C4%B1n",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u3057\u3083\u3079\u304f\u308a007",
#     "url": "http://twitter.com/search?q=%23%E3%81%97%E3%82%83%E3%81%B9%E3%81%8F%E3%82%8A007",
#     "promoted_content": null,
#     "query": "%23%E3%81%97%E3%82%83%E3%81%B9%E3%81%8F%E3%82%8A007",
#     "tweet_volume": 31623
#    },
#    {
#     "name": "Wrexham",
#     "url": "http://twitter.com/search?q=Wrexham",
#     "promoted_content": null,
#     "query": "Wrexham",
#     "tweet_volume": 12389
#    },
#    {
#     "name": "KIM TAEHYUNG",
#     "url": "http://twitter.com/search?q=%22KIM+TAEHYUNG%22",
#     "promoted_content": null,
#     "query": "%22KIM+TAEHYUNG%22",
#     "tweet_volume": 95800
#    },
#    {
#     "name": "Space Karen",
#     "url": "http://twitter.com/search?q=%22Space+Karen%22",
#     "promoted_content": null,
#     "query": "%22Space+Karen%22",
#     "tweet_volume": 17840
#    },
#    {
#     "name": "PSYCHO-PASS",
#     "url": "http://twitter.com/search?q=PSYCHO-PASS",
#     "promoted_content": null,
#     "query": "PSYCHO-PASS",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u82b1\u6fa4\u3055\u3093",
#     "url": "http://twitter.com/search?q=%E8%8A%B1%E6%BE%A4%E3%81%95%E3%82%93",
#     "promoted_content": null,
#     "query": "%E8%8A%B1%E6%BE%A4%E3%81%95%E3%82%93",
#     "tweet_volume": 18004
#    },
#    {
#     "name": "\u65e5\u91ce\u3055\u3093",
#     "url": "http://twitter.com/search?q=%E6%97%A5%E9%87%8E%E3%81%95%E3%82%93",
#     "promoted_content": null,
#     "query": "%E6%97%A5%E9%87%8E%E3%81%95%E3%82%93",
#     "tweet_volume": 16333
#    },
#    {
#     "name": "\u30b9\u30c8II",
#     "url": "http://twitter.com/search?q=%E3%82%B9%E3%83%88II",
#     "promoted_content": null,
#     "query": "%E3%82%B9%E3%83%88II",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u3048\u3044\u305f\u305d\u5352\u696d",
#     "url": "http://twitter.com/search?q=%E3%81%88%E3%81%84%E3%81%9F%E3%81%9D%E5%8D%92%E6%A5%AD",
#     "promoted_content": null,
#     "query": "%E3%81%88%E3%81%84%E3%81%9F%E3%81%9D%E5%8D%92%E6%A5%AD",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mahrez",
#     "url": "http://twitter.com/search?q=Mahrez",
#     "promoted_content": null,
#     "query": "Mahrez",
#     "tweet_volume": 13328
#    },
#    {
#     "name": "Kishimoto",
#     "url": "http://twitter.com/search?q=Kishimoto",
#     "promoted_content": null,
#     "query": "Kishimoto",
#     "tweet_volume": 46675
#    },
#    {
#     "name": "\u3056\u30fc\u3055\u3093",
#     "url": "http://twitter.com/search?q=%E3%81%96%E3%83%BC%E3%81%95%E3%82%93",
#     "promoted_content": null,
#     "query": "%E3%81%96%E3%83%BC%E3%81%95%E3%82%93",
#     "tweet_volume": 11183
#    },
#    {
#     "name": "ASIM RIAZ X DJ SNAKE",
#     "url": "http://twitter.com/search?q=%22ASIM+RIAZ+X+DJ+SNAKE%22",
#     "promoted_content": null,
#     "query": "%22ASIM+RIAZ+X+DJ+SNAKE%22",
#     "tweet_volume": 106288
#    },
#    {
#     "name": "Vcut",
#     "url": "http://twitter.com/search?q=Vcut",
#     "promoted_content": null,
#     "query": "Vcut",
#     "tweet_volume": 418096
#    },
#    {
#     "name": "Bruce Brown",
#     "url": "http://twitter.com/search?q=%22Bruce+Brown%22",
#     "promoted_content": null,
#     "query": "%22Bruce+Brown%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Providencia",
#     "url": "http://twitter.com/search?q=Providencia",
#     "promoted_content": null,
#     "query": "Providencia",
#     "tweet_volume": 25801
#    },
#    {
#     "name": "\u82b1\u6fa4\u9999\u83dc",
#     "url": "http://twitter.com/search?q=%E8%8A%B1%E6%BE%A4%E9%A6%99%E8%8F%9C",
#     "promoted_content": null,
#     "query": "%E8%8A%B1%E6%BE%A4%E9%A6%99%E8%8F%9C",
#     "tweet_volume": 23979
#    },
#    {
#     "name": "China Plague",
#     "url": "http://twitter.com/search?q=%22China+Plague%22",
#     "promoted_content": null,
#     "query": "%22China+Plague%22",
#     "tweet_volume": 18718
#    },
#    {
#     "name": "VIVI FROM LOONA",
#     "url": "http://twitter.com/search?q=%22VIVI+FROM+LOONA%22",
#     "promoted_content": null,
#     "query": "%22VIVI+FROM+LOONA%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Boruto",
#     "url": "http://twitter.com/search?q=Boruto",
#     "promoted_content": null,
#     "query": "Boruto",
#     "tweet_volume": 52559
#    },
#    {
#     "name": "mRNA",
#     "url": "http://twitter.com/search?q=mRNA",
#     "promoted_content": null,
#     "query": "mRNA",
#     "tweet_volume": 21361
#    },
#    {
#     "name": "herlock sholmes",
#     "url": "http://twitter.com/search?q=%22herlock+sholmes%22",
#     "promoted_content": null,
#     "query": "%22herlock+sholmes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u6cb3\u5408\u304f\u3093",
#     "url": "http://twitter.com/search?q=%E6%B2%B3%E5%90%88%E3%81%8F%E3%82%93",
#     "promoted_content": null,
#     "query": "%E6%B2%B3%E5%90%88%E3%81%8F%E3%82%93",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kanal \u0130stanbul",
#     "url": "http://twitter.com/search?q=%22Kanal+%C4%B0stanbul%22",
#     "promoted_content": null,
#     "query": "%22Kanal+%C4%B0stanbul%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "WHAT'S HAPPENING ON MAMA",
#     "url": "http://twitter.com/search?q=%22WHAT%27S+HAPPENING+ON+MAMA%22",
#     "promoted_content": null,
#     "query": "%22WHAT%27S+HAPPENING+ON+MAMA%22",
#     "tweet_volume": 32633
#    },
#    {
#     "name": "\u5bae\u91ce\u3055\u3093",
#     "url": "http://twitter.com/search?q=%E5%AE%AE%E9%87%8E%E3%81%95%E3%82%93",
#     "promoted_content": null,
#     "query": "%E5%AE%AE%E9%87%8E%E3%81%95%E3%82%93",
#     "tweet_volume": 16672
#    },
#    {
#     "name": "San Andr\u00e9s",
#     "url": "http://twitter.com/search?q=%22San+Andr%C3%A9s%22",
#     "promoted_content": null,
#     "query": "%22San+Andr%C3%A9s%22",
#     "tweet_volume": 24121
#    },
#    {
#     "name": "\u3048\u3044\u3061\u3083\u3093",
#     "url": "http://twitter.com/search?q=%E3%81%88%E3%81%84%E3%81%A1%E3%82%83%E3%82%93",
#     "promoted_content": null,
#     "query": "%E3%81%88%E3%81%84%E3%81%A1%E3%82%83%E3%82%93",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trello",
#     "url": "http://twitter.com/search?q=Trello",
#     "promoted_content": null,
#     "query": "Trello",
#     "tweet_volume": null
#    },
#    {
#     "name": "Candace Owens",
#     "url": "http://twitter.com/search?q=%22Candace+Owens%22",
#     "promoted_content": null,
#     "query": "%22Candace+Owens%22",
#     "tweet_volume": 16572
#    },
#    {
#     "name": "Category 5",
#     "url": "http://twitter.com/search?q=%22Category+5%22",
#     "promoted_content": null,
#     "query": "%22Category+5%22",
#     "tweet_volume": 13122
#    },
#    {
#     "name": "#AlwaysBesideATEEZ",
#     "url": "http://twitter.com/search?q=%23AlwaysBesideATEEZ",
#     "promoted_content": null,
#     "query": "%23AlwaysBesideATEEZ",
#     "tweet_volume": 20341
#    },
#    {
#     "name": "#\uc5d0\uc774\ud2f0\uc988\uc758_\ube5b\ub098\ub294_\ubcc4_1117",
#     "url": "http://twitter.com/search?q=%23%EC%97%90%EC%9D%B4%ED%8B%B0%EC%A6%88%EC%9D%98_%EB%B9%9B%EB%82%98%EB%8A%94_%EB%B3%84_1117",
#     "promoted_content": null,
#     "query": "%23%EC%97%90%EC%9D%B4%ED%8B%B0%EC%A6%88%EC%9D%98_%EB%B9%9B%EB%82%98%EB%8A%94_%EB%B3%84_1117",
#     "tweet_volume": 20155
#    },
#    {
#     "name": "#Dynamite600M",
#     "url": "http://twitter.com/search?q=%23Dynamite600M",
#     "promoted_content": null,
#     "query": "%23Dynamite600M",
#     "tweet_volume": 20109
#    },
#    {
#     "name": "#EstoyDeBlackEnPcComponentes",
#     "url": "http://twitter.com/search?q=%23EstoyDeBlackEnPcComponentes",
#     "promoted_content": null,
#     "query": "%23EstoyDeBlackEnPcComponentes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Aespa_Is_Here",
#     "url": "http://twitter.com/search?q=%23Aespa_Is_Here",
#     "promoted_content": null,
#     "query": "%23Aespa_Is_Here",
#     "tweet_volume": 47185
#    },
#    {
#     "name": "#\u95a2\u30b8\u30e3\u30cb\u30af\u30ed\u30cb\u30af\u30ebF",
#     "url": "http://twitter.com/search?q=%23%E9%96%A2%E3%82%B8%E3%83%A3%E3%83%8B%E3%82%AF%E3%83%AD%E3%83%8B%E3%82%AF%E3%83%ABF",
#     "promoted_content": null,
#     "query": "%23%E9%96%A2%E3%82%B8%E3%83%A3%E3%83%8B%E3%82%AF%E3%83%AD%E3%83%8B%E3%82%AF%E3%83%ABF",
#     "tweet_volume": 11891
#    },
#    {
#     "name": "#\uc5d0\uc2a4\ud30c\uc758_\ucc2c\ub780\ud55c_\uccab\uac78\uc74c",
#     "url": "http://twitter.com/search?q=%23%EC%97%90%EC%8A%A4%ED%8C%8C%EC%9D%98_%EC%B0%AC%EB%9E%80%ED%95%9C_%EC%B2%AB%EA%B1%B8%EC%9D%8C",
#     "promoted_content": null,
#     "query": "%23%EC%97%90%EC%8A%A4%ED%8C%8C%EC%9D%98_%EC%B0%AC%EB%9E%80%ED%95%9C_%EC%B2%AB%EA%B1%B8%EC%9D%8C",
#     "tweet_volume": 48464
#    },
#    {
#     "name": "#ATINYDAY",
#     "url": "http://twitter.com/search?q=%23ATINYDAY",
#     "promoted_content": null,
#     "query": "%23ATINYDAY",
#     "tweet_volume": 40463
#    },
#    {
#     "name": "#MondayMotivation",
#     "url": "http://twitter.com/search?q=%23MondayMotivation",
#     "promoted_content": null,
#     "query": "%23MondayMotivation",
#     "tweet_volume": 64115
#    },
#    {
#     "name": "#uominiedonne",
#     "url": "http://twitter.com/search?q=%23uominiedonne",
#     "promoted_content": null,
#     "query": "%23uominiedonne",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0e41\u0e1b\u0e25\u0e23\u0e31\u0e01EP5",
#     "url": "http://twitter.com/search?q=%23%E0%B9%81%E0%B8%9B%E0%B8%A5%E0%B8%A3%E0%B8%B1%E0%B8%81EP5",
#     "promoted_content": null,
#     "query": "%23%E0%B9%81%E0%B8%9B%E0%B8%A5%E0%B8%A3%E0%B8%B1%E0%B8%81EP5",
#     "tweet_volume": 45780
#    },
#    {
#     "name": "#PS5yMediaMarkt",
#     "url": "http://twitter.com/search?q=%23PS5yMediaMarkt",
#     "promoted_content": null,
#     "query": "%23PS5yMediaMarkt",
#     "tweet_volume": 10469
#    },
#    {
#     "name": "#SeAcercaElBLackChollometro",
#     "url": "http://twitter.com/search?q=%23SeAcercaElBLackChollometro",
#     "promoted_content": null,
#     "query": "%23SeAcercaElBLackChollometro",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u9ed2\u5c3e\u9244\u6717\u8a95\u751f\u796d2020",
#     "url": "http://twitter.com/search?q=%23%E9%BB%92%E5%B0%BE%E9%89%84%E6%9C%97%E8%AA%95%E7%94%9F%E7%A5%AD2020",
#     "promoted_content": null,
#     "query": "%23%E9%BB%92%E5%B0%BE%E9%89%84%E6%9C%97%E8%AA%95%E7%94%9F%E7%A5%AD2020",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-11-16T15:13:28Z",
#   "created_at": "2020-11-15T12:50:47Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "trends": [
#    {
#     "name": "#MondayMotivation",
#     "url": "http://twitter.com/search?q=%23MondayMotivation",
#     "promoted_content": null,
#     "query": "%23MondayMotivation",
#     "tweet_volume": 64115
#    },
#    {
#     "name": "Moderna",
#     "url": "http://twitter.com/search?q=Moderna",
#     "promoted_content": null,
#     "query": "Moderna",
#     "tweet_volume": 185800
#    },
#    {
#     "name": "#mondaythoughts",
#     "url": "http://twitter.com/search?q=%23mondaythoughts",
#     "promoted_content": null,
#     "query": "%23mondaythoughts",
#     "tweet_volume": 44208
#    },
#    {
#     "name": "Space Karen",
#     "url": "http://twitter.com/search?q=%22Space+Karen%22",
#     "promoted_content": null,
#     "query": "%22Space+Karen%22",
#     "tweet_volume": 17928
#    },
#    {
#     "name": "#FreePcMonday",
#     "url": "http://twitter.com/search?q=%23FreePcMonday",
#     "promoted_content": null,
#     "query": "%23FreePcMonday",
#     "tweet_volume": 11493
#    },
#    {
#     "name": "#MondayMorning",
#     "url": "http://twitter.com/search?q=%23MondayMorning",
#     "promoted_content": null,
#     "query": "%23MondayMorning",
#     "tweet_volume": 16432
#    },
#    {
#     "name": "#PatIDontWantToOverreactBUT",
#     "url": "http://twitter.com/search?q=%23PatIDontWantToOverreactBUT",
#     "promoted_content": null,
#     "query": "%23PatIDontWantToOverreactBUT",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bruce Brown",
#     "url": "http://twitter.com/search?q=%22Bruce+Brown%22",
#     "promoted_content": null,
#     "query": "%22Bruce+Brown%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Candace Owens",
#     "url": "http://twitter.com/search?q=%22Candace+Owens%22",
#     "promoted_content": null,
#     "query": "%22Candace+Owens%22",
#     "tweet_volume": 16663
#    },
#    {
#     "name": "Category 5",
#     "url": "http://twitter.com/search?q=%22Category+5%22",
#     "promoted_content": null,
#     "query": "%22Category+5%22",
#     "tweet_volume": 13122
#    },
#    {
#     "name": "Musa",
#     "url": "http://twitter.com/search?q=Musa",
#     "promoted_content": null,
#     "query": "Musa",
#     "tweet_volume": 24797
#    },
#    {
#     "name": "mRNA",
#     "url": "http://twitter.com/search?q=mRNA",
#     "promoted_content": null,
#     "query": "mRNA",
#     "tweet_volume": 21361
#    },
#    {
#     "name": "China Plague",
#     "url": "http://twitter.com/search?q=%22China+Plague%22",
#     "promoted_content": null,
#     "query": "%22China+Plague%22",
#     "tweet_volume": 18540
#    },
#    {
#     "name": "Victory Monday",
#     "url": "http://twitter.com/search?q=%22Victory+Monday%22",
#     "promoted_content": null,
#     "query": "%22Victory+Monday%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cat 5",
#     "url": "http://twitter.com/search?q=%22Cat+5%22",
#     "promoted_content": null,
#     "query": "%22Cat+5%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Really GREAT",
#     "url": "http://twitter.com/search?q=%22Really+GREAT%22",
#     "promoted_content": null,
#     "query": "%22Really+GREAT%22",
#     "tweet_volume": 60004
#    },
#    {
#     "name": "Herlock Sholmes",
#     "url": "http://twitter.com/search?q=%22Herlock+Sholmes%22",
#     "promoted_content": null,
#     "query": "%22Herlock+Sholmes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Historians",
#     "url": "http://twitter.com/search?q=Historians",
#     "promoted_content": null,
#     "query": "Historians",
#     "tweet_volume": 23540
#    },
#    {
#     "name": "Central America",
#     "url": "http://twitter.com/search?q=%22Central+America%22",
#     "promoted_content": null,
#     "query": "%22Central+America%22",
#     "tweet_volume": 14744
#    },
#    {
#     "name": "VIVI FROM LOONA",
#     "url": "http://twitter.com/search?q=%22VIVI+FROM+LOONA%22",
#     "promoted_content": null,
#     "query": "%22VIVI+FROM+LOONA%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nicaragua",
#     "url": "http://twitter.com/search?q=Nicaragua",
#     "promoted_content": null,
#     "query": "Nicaragua",
#     "tweet_volume": 49025
#    },
#    {
#     "name": "NO YOU DIDN'T",
#     "url": "http://twitter.com/search?q=%22NO+YOU+DIDN%27T%22",
#     "promoted_content": null,
#     "query": "%22NO+YOU+DIDN%27T%22",
#     "tweet_volume": 38148
#    },
#    {
#     "name": "Wrexham",
#     "url": "http://twitter.com/search?q=Wrexham",
#     "promoted_content": null,
#     "query": "Wrexham",
#     "tweet_volume": 12473
#    },
#    {
#     "name": "Scott Atlas",
#     "url": "http://twitter.com/search?q=%22Scott+Atlas%22",
#     "promoted_content": null,
#     "query": "%22Scott+Atlas%22",
#     "tweet_volume": 41703
#    },
#    {
#     "name": "Kishimoto",
#     "url": "http://twitter.com/search?q=Kishimoto",
#     "promoted_content": null,
#     "query": "Kishimoto",
#     "tweet_volume": 46675
#    },
#    {
#     "name": "Another Monday",
#     "url": "http://twitter.com/search?q=%22Another+Monday%22",
#     "promoted_content": null,
#     "query": "%22Another+Monday%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Harry Styles",
#     "url": "http://twitter.com/search?q=%22Harry+Styles%22",
#     "promoted_content": null,
#     "query": "%22Harry+Styles%22",
#     "tweet_volume": 179994
#    },
#    {
#     "name": "The Great Reset",
#     "url": "http://twitter.com/search?q=%22The+Great+Reset%22",
#     "promoted_content": null,
#     "query": "%22The+Great+Reset%22",
#     "tweet_volume": 94021
#    },
#    {
#     "name": "Meek",
#     "url": "http://twitter.com/search?q=Meek",
#     "promoted_content": null,
#     "query": "Meek",
#     "tweet_volume": 16638
#    },
#    {
#     "name": "KIM TAEHYUNG",
#     "url": "http://twitter.com/search?q=%22KIM+TAEHYUNG%22",
#     "promoted_content": null,
#     "query": "%22KIM+TAEHYUNG%22",
#     "tweet_volume": 95800
#    },
#    {
#     "name": "Troy Weaver",
#     "url": "http://twitter.com/search?q=%22Troy+Weaver%22",
#     "promoted_content": null,
#     "query": "%22Troy+Weaver%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jay Clayton",
#     "url": "http://twitter.com/search?q=%22Jay+Clayton%22",
#     "promoted_content": null,
#     "query": "%22Jay+Clayton%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "John Tesh",
#     "url": "http://twitter.com/search?q=%22John+Tesh%22",
#     "promoted_content": null,
#     "query": "%22John+Tesh%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "New Week",
#     "url": "http://twitter.com/search?q=%22New+Week%22",
#     "promoted_content": null,
#     "query": "%22New+Week%22",
#     "tweet_volume": 104315
#    },
#    {
#     "name": "Richie Rich",
#     "url": "http://twitter.com/search?q=%22Richie+Rich%22",
#     "promoted_content": null,
#     "query": "%22Richie+Rich%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "YOU LOST THE ELECTION",
#     "url": "http://twitter.com/search?q=%22YOU+LOST+THE+ELECTION%22",
#     "promoted_content": null,
#     "query": "%22YOU+LOST+THE+ELECTION%22",
#     "tweet_volume": 35989
#    },
#    {
#     "name": "I WON",
#     "url": "http://twitter.com/search?q=%22I+WON%22",
#     "promoted_content": null,
#     "query": "%22I+WON%22",
#     "tweet_volume": 637882
#    },
#    {
#     "name": "on your watch",
#     "url": "http://twitter.com/search?q=%22on+your+watch%22",
#     "promoted_content": null,
#     "query": "%22on+your+watch%22",
#     "tweet_volume": 47127
#    },
#    {
#     "name": "Trump Plague",
#     "url": "http://twitter.com/search?q=%22Trump+Plague%22",
#     "promoted_content": null,
#     "query": "%22Trump+Plague%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ritt Momney",
#     "url": "http://twitter.com/search?q=%22Ritt+Momney%22",
#     "promoted_content": null,
#     "query": "%22Ritt+Momney%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "RIP DJ Screw",
#     "url": "http://twitter.com/search?q=%22RIP+DJ+Screw%22",
#     "promoted_content": null,
#     "query": "%22RIP+DJ+Screw%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Corinne Bailey Rae",
#     "url": "http://twitter.com/search?q=%22Corinne+Bailey+Rae%22",
#     "promoted_content": null,
#     "query": "%22Corinne+Bailey+Rae%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Today is Monday",
#     "url": "http://twitter.com/search?q=%22Today+is+Monday%22",
#     "promoted_content": null,
#     "query": "%22Today+is+Monday%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Official Sources",
#     "url": "http://twitter.com/search?q=%22Official+Sources%22",
#     "promoted_content": null,
#     "query": "%22Official+Sources%22",
#     "tweet_volume": 31065
#    },
#    {
#     "name": "Boruto",
#     "url": "http://twitter.com/search?q=Boruto",
#     "promoted_content": null,
#     "query": "Boruto",
#     "tweet_volume": 52637
#    },
#    {
#     "name": "Jake Paul",
#     "url": "http://twitter.com/search?q=%22Jake+Paul%22",
#     "promoted_content": null,
#     "query": "%22Jake+Paul%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Azar",
#     "url": "http://twitter.com/search?q=Azar",
#     "promoted_content": null,
#     "query": "Azar",
#     "tweet_volume": 13124
#    },
#    {
#     "name": "happy monday everyone",
#     "url": "http://twitter.com/search?q=%22happy+monday+everyone%22",
#     "promoted_content": null,
#     "query": "%22happy+monday+everyone%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Feliz Lunes",
#     "url": "http://twitter.com/search?q=%22Feliz+Lunes%22",
#     "promoted_content": null,
#     "query": "%22Feliz+Lunes%22",
#     "tweet_volume": 16947
#    },
#    {
#     "name": "Hello Monday",
#     "url": "http://twitter.com/search?q=%22Hello+Monday%22",
#     "promoted_content": null,
#     "query": "%22Hello+Monday%22",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-11-16T15:13:29Z",
#   "created_at": "2020-11-14T20:58:43Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print (common_trends)
# Out:
# {'Kishimoto', 'VIVI FROM LOONA', 'Candace Owens', 'Category 5', 'Boruto', 'Moderna', 'China Plague', 'Wrexham', 'KIM TAEHYUNG', 'Space Karen', 'mRNA', '#MondayMotivation', 'Bruce Brown'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

import urllib

q = '#Diwali' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print ("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in urllib.parse.unquote_plus(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print (json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 300
# Length of statuses 400
# Length of statuses 500
# {
#  "created_at": "Mon Nov 16 15:20:24 +0000 2020",
#  "id": 1328357259362017280,
#  "id_str": "1328357259362017280",
#  "text": "RT @DiariesRajwar: 32 RR #Rafiabad #Army under aegis of #Kiloforce distributed sweets to #children in Parrypora #Govt #Middle #School on oc\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "Rafiabad",
#     "indices": [
#      25,
#      34
#     ]
#    },
#    {
#     "text": "Army",
#     "indices": [
#      35,
#      40
#     ]
#    },
#    {
#     "text": "Kiloforce",
#     "indices": [
#      56,
#      66
#     ]
#    },
#    {
#     "text": "children",
#     "indices": [
#      89,
#      98
#     ]
#    },
#    {
#     "text": "Govt",
#     "indices": [
#      112,
#      117
#     ]
#    },
#    {
#     "text": "Middle",
#     "indices": [
#      118,
#      125
#     ]
#    },
#    {
#     "text": "School",
#     "indices": [
#      126,
#      133
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "DiariesRajwar",
#     "name": "rajwar_diaries",
#     "id": 1307722925374488576,
#     "id_str": "1307722925374488576",
#     "indices": [
#      3,
#      17
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1314166115065491456,
#   "id_str": "1314166115065491456",
#   "name": "RITURAJKONWAR",
#   "screen_name": "RITURAJ20312784",
#   "location": "",
#   "description": "game",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 1,
#   "friends_count": 11,
#   "listed_count": 0,
#   "created_at": "Thu Oct 08 11:30:16 +0000 2020",
#   "favourites_count": 434,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 403,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": true,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sat Nov 14 12:27:18 +0000 2020",
#   "id": 1327588919311941632,
#   "id_str": "1327588919311941632",
#   "text": "32 RR #Rafiabad #Army under aegis of #Kiloforce distributed sweets to #children in Parrypora #Govt #Middle #School\u2026 https://t.co/s0Bv7kUrMR",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "Rafiabad",
#      "indices": [
#       6,
#       15
#      ]
#     },
#     {
#      "text": "Army",
#      "indices": [
#       16,
#       21
#      ]
#     },
#     {
#      "text": "Kiloforce",
#      "indices": [
#       37,
#       47
#      ]
#     },
#     {
#      "text": "children",
#      "indices": [
#       70,
#       79
#      ]
#     },
#     {
#      "text": "Govt",
#      "indices": [
#       93,
#       98
#      ]
#     },
#     {
#      "text": "Middle",
#      "indices": [
#       99,
#       106
#      ]
#     },
#     {
#      "text": "School",
#      "indices": [
#       107,
#       114
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/s0Bv7kUrMR",
#      "expanded_url": "https://twitter.com/i/web/status/1327588919311941632",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       116,
#       139
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1307722925374488576,
#    "id_str": "1307722925374488576",
#    "name": "rajwar_diaries",
#    "screen_name": "DiariesRajwar",
#    "location": "",
#    "description": "blogger",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 795,
#    "friends_count": 8,
#    "listed_count": 0,
#    "created_at": "Sun Sep 20 16:47:18 +0000 2020",
#    "favourites_count": 217,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 326,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1307723162386231296/-AkHZgRE_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1307723162386231296/-AkHZgRE_normal.jpg",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 234,
#   "favorite_count": 268,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 234,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print (t['retweet_count'])
print (t['retweeted_status'])

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# 23
# {'contributors': None, 'truncated': False, 'text': '#MentionSomeoneImportantForYou God.', 'in_reply_to_status_id': None, 'id': 316944833233186816, 'favorite_count': 0, 'source': 'web', 'retweeted': False, 'coordinates': None, 'entities': {'user_mentions': [], 'hashtags': [{'indices': [0, 30], 'text': 'MentionSomeoneImportantForYou'}], 'urls': []}, 'in_reply_to_screen_name': None, 'in_reply_to_user_id': None, 'retweet_count': 23, 'id_str': '316944833233186816', 'favorited': False, 'user': {'follow_request_sent': None, 'profile_use_background_image': True, 'default_profile_image': False, 'id': 56259379, 'verified': False, 'profile_text_color': '3C3940', 'profile_image_url_https': 'https://si0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', 'profile_sidebar_fill_color': '95E8EC', 'entities': {'url': {'urls': [{'url': 'http://t.co/yRX89YM4J0', 'indices': [0, 22], 'expanded_url': 'http://www.datpiff.com/mixtapes-detail.php?id=470069', 'display_url': 'datpiff.com/mixtapes-detai…'}]}, 'description': {'urls': []}}, 'followers_count': 105041, 'profile_sidebar_border_color': '000000', 'id_str': '56259379', 'profile_background_color': '000000', 'listed_count': 64, 'profile_background_image_url_https': 'https://si0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', 'utc_offset': -18000, 'statuses_count': 16691, 'description': '#TheseAreTheWordsISaid LP', 'friends_count': 59615, 'location': '', 'profile_link_color': '91785A', 'profile_image_url': 'http://a0.twimg.com/profile_images/3429999131/c22f74b56d0e0bf6350ceb00aae0aa0a_normal.jpeg', 'following': None, 'geo_enabled': True, 'profile_banner_url': 'https://si0.twimg.com/profile_banners/56259379/1363388572', 'profile_background_image_url': 'http://a0.twimg.com/profile_background_images/824774581/a0c35bcecb5642e0e17c707372fc393e.jpeg', 'screen_name': 'hassanmusician', 'lang': 'en', 'profile_background_tile': False, 'favourites_count': 6142, 'name': 'Download the NEW LP!', 'notifications': None, 'url': 'http://t.co/yRX89YM4J0', 'created_at': 'Mon Jul 13 02:18:25 +0000 2009', 'contributors_enabled': False, 'time_zone': 'Eastern Time (US & Canada)', 'protected': False, 'default_profile': False, 'is_translator': False}, 'geo': None, 'in_reply_to_user_id_str': None, 'lang': 'en', 'created_at': 'Wed Mar 27 16:08:31 +0000 2013', 'in_reply_to_status_id_str': None, 'place': None, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}}

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print (json.dumps(status_texts[0:5], indent=1))
print (json.dumps(screen_names[0:5], indent=1)) 
print (json.dumps(hashtags[0:5], indent=1))
print (json.dumps(words[0:5], indent=1))
# Out:
# [
#  "\u201c@KathleenMariee_: #MentionSomeOneImportantForYou @AhhlicksCruise , @itsravennn_cx ,@kandykisses_13 , @BMOLOGY\u201d\ud83d\udc4d",
#  "#MentionSomeoneImportantForYou My bf @Linkin_Sunrise.",
#  "RT @hassanmusician: #MentionSomeoneImportantForYou God.",
#  "#MentionSomeoneImportantForYou @Louis_Tomlinson",
#  "#MentionSomeoneImportantForYou @Delta_Universe"
# ]
# [
#  "KathleenMariee_",
#  "AhhlicksCruise",
#  "itsravennn_cx",
#  "kandykisses_13",
#  "BMOLOGY"
# ]
# [
#  "MentionSomeOneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou",
#  "MentionSomeoneImportantForYou"
# ]
# [
#  "\u201c@KathleenMariee_:",
#  "#MentionSomeOneImportantForYou",
#  "@AhhlicksCruise",
#  ",",
#  "@itsravennn_cx"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:10]) # top 10
    print()
# Out:
# [('#MentionSomeoneImportantForYou', 92), ('RT', 34), ('my', 10), (',', 6), ('&lt;3', 6), ('@justinbieber', 6), ('My', 5), ('I', 4), ('and', 4), ('love', 3)]
#
# [('justinbieber', 6), ('Cavillafuerte', 2), ('Kid_Charliej', 2), ('KathleenMariee_', 1), ('AhhlicksCruise', 1), ('itsravennn_cx', 1), ('kandykisses_13', 1), ('BMOLOGY', 1), ('Linkin_Sunrise', 1), ('hassanmusician', 1)]
#
# [('MentionSomeoneImportantForYou', 94), ('mentionsomeoneimportantforyou', 3), ('MentionSomeOneImportantForYou', 1), ('NoHomo', 1), ('bebesito', 1), ('MyHeart', 1), ('Love', 1)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print (pt)
# Out:
# +--------------------------------+-------+
# | Word                           | Count |
# +--------------------------------+-------+
# | #MentionSomeoneImportantForYou |    92 |
# | RT                             |    34 |
# | my                             |    10 |
# | ,                              |     6 |
# | &lt;3                          |     6 |
# | @justinbieber                  |     6 |
# | My                             |     5 |
# | I                              |     4 |
# | and                            |     4 |
# | love                           |     3 |
# +--------------------------------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | justinbieber    |     6 |
# | Cavillafuerte   |     2 |
# | Kid_Charliej    |     2 |
# | KathleenMariee_ |     1 |
# | AhhlicksCruise  |     1 |
# | itsravennn_cx   |     1 |
# | kandykisses_13  |     1 |
# | BMOLOGY         |     1 |
# | Linkin_Sunrise  |     1 |
# | hassanmusician  |     1 |
# +-----------------+-------+
# +-------------------------------+-------+
# | Hashtag                       | Count |
# +-------------------------------+-------+
# | MentionSomeoneImportantForYou |    94 |
# | mentionsomeoneimportantforyou |     3 |
# | MentionSomeOneImportantForYou |     1 |
# | NoHomo                        |     1 |
# | bebesito                      |     1 |
# | MyHeart                       |     1 |
# | Love                          |     1 |
# +-------------------------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print (lexical_diversity(words))
print (lexical_diversity(screen_names))
print (lexical_diversity(hashtags))
print (average_words(status_texts))
# Out:
# 0.6761061946902654
# 0.9554140127388535
# 0.06862745098039216
# 5.76530612244898

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (st['retweet_count'], 
             st['retweeted_status']['user']['screen_name'],
             st['text']) 
            
            for st in statuses
                if 'retweeted_status' in st
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print (pt)
# Out:
# +-------+----------------+----------------------------------------------------+
# | Count | Screen Name    | Text                                               |
# +-------+----------------+----------------------------------------------------+
# | 23    | hassanmusician | RT @hassanmusician: #MentionSomeoneImportantForYou |
# |       |                | God.                                               |
# | 21    | HSweethearts   | RT @HSweethearts: #MentionSomeoneImportantForYou   |
# |       |                | my high school sweetheart ❤💋                      |
# | 15    | LosAlejandro_  | RT @LosAlejandro_: ¿Nadie te menciono en           |
# |       |                | "#MentionSomeoneImportantForYou"? JAJAJAJAJAJAJAJA |
# |       |                | JAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJAJA Ven, ...  |
# | 9     | SCOTTSUMME     | RT @SCOTTSUMME: #MentionSomeoneImportantForYou My  |
# |       |                | Mum. Shes loving, caring, strong, all in one. I    |
# |       |                | love her so much ❤❤❤❤                              |
# | 7     | degrassihaha   | RT @degrassihaha: #MentionSomeoneImportantForYou I |
# |       |                | can't put every Degrassi cast member, crew member, |
# |       |                | and writer in just one tweet....                   |
# +-------+----------------+----------------------------------------------------+

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print ([r['user']['screen_name'] for r in _retweets])
# Out:
# ['jyeee', 'Ceejaynatics', 'LoveKyana18', 'kidamgos', 'asdfghjbl', 'josellexseraspi', 'anneyyeong']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
import matplotlib.pyplot as plt

word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.show()

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')
plt.show()
print (counts)
# Out:
# [23, 1, 21, 1, 5, 2, 2, 2, 3, 1, 1, 1, 1, 9, 1, 1, 1, 15, 1, 1, 1, 2, 1, 1, 7, 6, 1, 3, 1, 1, 1, 1, 1]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them
import math

counts = [math.log(count) for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')
plt.show()
